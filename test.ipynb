# %%
print('Hello world')

# %% [markdown]
# teststststsst

# %%
base = 9
exponent = 2

print(base ** exponent) #9의 2제곱
# Out:
# 81

# %%
name = "asdf"
name3 = name*3
print(name3)
# Out:
# asdfasdfasdf
